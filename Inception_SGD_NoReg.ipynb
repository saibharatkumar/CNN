# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import datetime as dt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
y_proc=np.zeros((50000,100))
for i in range(0,50000):
    y_proc[i][y_train[i][0]]=1
y_test_proc=np.zeros((10000,100))
for i in range(0,10000):
    y_test_proc[i][y_test[i][0]]=1
y_proc.shape
input_shape=(32,32,3)
y_test_proc[0]
x_train=x_train.astype('float')/255
x_test=x_test.astype('float')/255

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False)  # randomly flip images
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %%
inputs = keras.Input(shape=input_shape)
x = layers.Conv2D(32, 3, activation='elu')(inputs)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)


#Inception1


conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)

conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_2 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_2)

conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2

conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception3
conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
conv_11 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_1)

conv_12 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_21 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_2)

conv_22 = layers.Conv2D(32, (3,1), padding='same', activation='elu')(conv_2)

conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

x = layers.concatenate([conv_11,conv_12,conv_3,conv_4,conv_21,conv_22], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
# conv_11 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_1)

# conv_12 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_21 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_2)

# conv_22 = layers.Conv2D(32, (3,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#end

# x = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)



# x = layers.MaxPooling2D(2)(x)
x = layers.Conv2D(32, 3, activation='relu')(x)
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.AveragePooling2D(4)(x)
x=layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
outputs = layers.Dense(100, activation='softmax')(x)

inception_net_model = keras.Model(inputs, outputs)

# %%
inception_net_model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 30, 30, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 26, 26, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 26, 26, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 32)   9248        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 22, 22, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 20, 20, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 20, 20, 32)   1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 32)   9248        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 20, 20, 32)   1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 20, 20, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 20, 20, 32)   9248        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 20, 32)   9248        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 20, 32)   1056        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 20, 20, 32)   1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 20, 128)  0           conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 20, 20, 32)   4128        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 20, 20, 32)   4128        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 128)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 20, 20, 32)   4128        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 20, 20, 32)   4128        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 20, 128)  0           conv2d_17[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 20, 20, 32)   4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 32)   9248        conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 20, 20, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 20, 20, 32)   4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 20, 20, 32)   3104        conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 20, 20, 32)   7200        conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 20, 20, 32)   4128        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 20, 20, 32)   4128        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 20, 20, 32)   3104        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 20, 20, 32)   3104        conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 20, 20, 192)  0           conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 18, 18, 32)   55328       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 64)   18496       conv2d_32[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 64)     0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          262400      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          25700       dense[0][0]
# ==================================================================================================
# Total params: 543,012
# Trainable params: 543,012
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %load_ext tensorboard
tensor_board = tf.keras.callbacks.TensorBoard(log_dir='tensorboard',histogram_freq=1)
inception_net_model.compile(optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9),
              loss='categorical_crossentropy',
              metrics=['acc'])
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3,min_delta=0.005)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='inception_sgd_noreg.hdf5',
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    save_best_only=True)
# inception_net_model.fit(x_train,y_proc,batch_size=200,validation_data=(x_test,y_test_proc),epochs=50,callbacks=[callback,model_checkpoint_callback])
output=inception_net_model.fit_generator(datagen.flow(x_train,y_proc,batch_size = 200), epochs = 100, validation_data = (x_test,y_test_proc),callbacks = [tensor_board,callback,model_checkpoint_callback])
# Out:
# WARNING:tensorflow:From <ipython-input-8-90451f61729f>:14: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
#   1/250 [..............................] - ETA: 0s - loss: 4.6035 - acc: 0.0100WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 250/250 [==============================] - 37s 148ms/step - loss: 4.4001 - acc: 0.0369 - val_loss: 4.0303 - val_acc: 0.0767
# Epoch 2/100
# 250/250 [==============================] - 36s 145ms/step - loss: 3.8440 - acc: 0.1085 - val_loss: 3.5914 - val_acc: 0.1546
# Epoch 3/100
# 250/250 [==============================] - 37s 147ms/step - loss: 3.5522 - acc: 0.1572 - val_loss: 3.3926 - val_acc: 0.1919
# Epoch 4/100
# 250/250 [==============================] - 37s 146ms/step - loss: 3.3489 - acc: 0.1954 - val_loss: 3.2289 - val_acc: 0.2183
# Epoch 5/100
# 250/250 [==============================] - 36s 145ms/step - loss: 3.1675 - acc: 0.2253 - val_loss: 3.1108 - val_acc: 0.2395
# Epoch 6/100
# 250/250 [==============================] - 36s 145ms/step - loss: 3.0267 - acc: 0.2508 - val_loss: 2.9363 - val_acc: 0.2723
# Epoch 7/100
# 250/250 [==============================] - 36s 146ms/step - loss: 2.9137 - acc: 0.2721 - val_loss: 2.8916 - val_acc: 0.2866
# Epoch 8/100
# 250/250 [==============================] - 36s 145ms/step - loss: 2.8067 - acc: 0.2919 - val_loss: 2.8236 - val_acc: 0.2925
# Epoch 9/100
# 250/250 [==============================] - 36s 146ms/step - loss: 2.7132 - acc: 0.3140 - val_loss: 2.8027 - val_acc: 0.3004
# Epoch 10/100
# 250/250 [==============================] - 36s 145ms/step - loss: 2.6260 - acc: 0.3289 - val_loss: 2.7381 - val_acc: 0.3157
# Epoch 11/100
# 250/250 [==============================] - 37s 147ms/step - loss: 2.5651 - acc: 0.3428 - val_loss: 2.5709 - val_acc: 0.3463
# Epoch 12/100
# 250/250 [==============================] - 37s 147ms/step - loss: 2.4813 - acc: 0.3571 - val_loss: 2.6110 - val_acc: 0.3517
# Epoch 13/100
# 250/250 [==============================] - 36s 146ms/step - loss: 2.4224 - acc: 0.3720 - val_loss: 2.6390 - val_acc: 0.3422
# Epoch 14/100
# 250/250 [==============================] - 36s 146ms/step - loss: 2.3741 - acc: 0.3824 - val_loss: 2.4769 - val_acc: 0.3633
# Epoch 15/100
# 250/250 [==============================] - 36s 145ms/step - loss: 2.3210 - acc: 0.3925 - val_loss: 2.4481 - val_acc: 0.3717
# Epoch 16/100
# 250/250 [==============================] - 36s 145ms/step - loss: 2.2897 - acc: 0.3984 - val_loss: 2.4484 - val_acc: 0.3697
# Epoch 17/100
# 250/250 [==============================] - 36s 145ms/step - loss: 2.2471 - acc: 0.4040 - val_loss: 2.3774 - val_acc: 0.3847
# Epoch 18/100
# 250/250 [==============================] - 36s 145ms/step - loss: 2.2111 - acc: 0.4157 - val_loss: 2.4305 - val_acc: 0.3794
# Epoch 19/100
# 250/250 [==============================] - 37s 146ms/step - loss: 2.1518 - acc: 0.4272 - val_loss: 2.2780 - val_acc: 0.4069
# Epoch 20/100
# 250/250 [==============================] - 36s 146ms/step - loss: 2.1156 - acc: 0.4358 - val_loss: 2.2185 - val_acc: 0.4195
# Epoch 21/100
# 250/250 [==============================] - 36s 143ms/step - loss: 2.0824 - acc: 0.4423 - val_loss: 2.1803 - val_acc: 0.4246
# Epoch 22/100
# 250/250 [==============================] - 36s 144ms/step - loss: 2.0561 - acc: 0.4492 - val_loss: 2.2105 - val_acc: 0.4251
# Epoch 23/100
# 250/250 [==============================] - 36s 143ms/step - loss: 2.0306 - acc: 0.4555 - val_loss: 2.1806 - val_acc: 0.4340
# Epoch 24/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.9975 - acc: 0.4609 - val_loss: 2.2447 - val_acc: 0.4215
# Epoch 25/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.9690 - acc: 0.4691 - val_loss: 2.1459 - val_acc: 0.4414
# Epoch 26/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.9538 - acc: 0.4736 - val_loss: 2.1345 - val_acc: 0.4382
# Epoch 27/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.9063 - acc: 0.4827 - val_loss: 2.2739 - val_acc: 0.4112
# Epoch 28/100
# 250/250 [==============================] - 37s 149ms/step - loss: 1.9000 - acc: 0.4858 - val_loss: 2.0933 - val_acc: 0.4460
# Epoch 29/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.8624 - acc: 0.4928 - val_loss: 2.0404 - val_acc: 0.4559
# Epoch 30/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.8363 - acc: 0.4972 - val_loss: 2.0366 - val_acc: 0.4629
# Epoch 31/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.8322 - acc: 0.5006 - val_loss: 2.0359 - val_acc: 0.4698
# Epoch 32/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.8080 - acc: 0.5024 - val_loss: 2.1796 - val_acc: 0.4337
# Epoch 33/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.7827 - acc: 0.5104 - val_loss: 2.0270 - val_acc: 0.4699
# Epoch 34/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.7560 - acc: 0.5161 - val_loss: 2.0174 - val_acc: 0.4707
# Epoch 35/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.7624 - acc: 0.5139 - val_loss: 2.0239 - val_acc: 0.4674
# Epoch 36/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.7361 - acc: 0.5216 - val_loss: 2.0869 - val_acc: 0.4584
# Epoch 37/100
# 250/250 [==============================] - 38s 153ms/step - loss: 1.7111 - acc: 0.5267 - val_loss: 2.0255 - val_acc: 0.4698
# Epoch 38/100
# 250/250 [==============================] - 37s 150ms/step - loss: 1.7183 - acc: 0.5244 - val_loss: 2.0644 - val_acc: 0.4610
# Epoch 39/100
# 250/250 [==============================] - 38s 151ms/step - loss: 1.6881 - acc: 0.5326 - val_loss: 2.3202 - val_acc: 0.4355
# Epoch 40/100
# 250/250 [==============================] - 38s 150ms/step - loss: 1.6724 - acc: 0.5357 - val_loss: 2.0228 - val_acc: 0.4756
# Epoch 41/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.6592 - acc: 0.5401 - val_loss: 1.9914 - val_acc: 0.4775
# Epoch 42/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.6381 - acc: 0.5436 - val_loss: 2.0781 - val_acc: 0.4663
# Epoch 43/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.6164 - acc: 0.5487 - val_loss: 1.9153 - val_acc: 0.4940
# Epoch 44/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.6162 - acc: 0.5488 - val_loss: 1.9902 - val_acc: 0.4771
# Epoch 45/100
# 250/250 [==============================] - 38s 151ms/step - loss: 1.5925 - acc: 0.5555 - val_loss: 1.9218 - val_acc: 0.4951
# Epoch 46/100
# 250/250 [==============================] - 38s 150ms/step - loss: 1.5827 - acc: 0.5571 - val_loss: 1.9701 - val_acc: 0.4842
# Epoch 47/100
# 250/250 [==============================] - 37s 150ms/step - loss: 1.5740 - acc: 0.5564 - val_loss: 2.0346 - val_acc: 0.4734
# Epoch 48/100
# 250/250 [==============================] - 37s 149ms/step - loss: 1.5635 - acc: 0.5633 - val_loss: 1.9012 - val_acc: 0.4951
# Epoch 49/100
# 250/250 [==============================] - 37s 150ms/step - loss: 1.5426 - acc: 0.5668 - val_loss: 2.0153 - val_acc: 0.4729
# Epoch 50/100
# 250/250 [==============================] - 37s 149ms/step - loss: 1.5459 - acc: 0.5648 - val_loss: 1.8804 - val_acc: 0.5064
# Epoch 51/100
# 250/250 [==============================] - 37s 149ms/step - loss: 1.5226 - acc: 0.5704 - val_loss: 2.0416 - val_acc: 0.4748
# Epoch 52/100
# 250/250 [==============================] - 37s 149ms/step - loss: 1.5167 - acc: 0.5722 - val_loss: 2.0136 - val_acc: 0.4834
# Epoch 53/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.4894 - acc: 0.5797 - val_loss: 1.9949 - val_acc: 0.4904
# Epoch 54/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.4990 - acc: 0.5766 - val_loss: 1.9922 - val_acc: 0.4892
# Epoch 55/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.4960 - acc: 0.5769 - val_loss: 1.8568 - val_acc: 0.5068
# Epoch 56/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.4764 - acc: 0.5808 - val_loss: 1.9046 - val_acc: 0.5033
# Epoch 57/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.4686 - acc: 0.5815 - val_loss: 1.9620 - val_acc: 0.4874
# Epoch 58/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.4613 - acc: 0.5840 - val_loss: 1.9688 - val_acc: 0.4997
# Epoch 59/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.4576 - acc: 0.5839 - val_loss: 2.0652 - val_acc: 0.4780
# Epoch 60/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.4508 - acc: 0.5886 - val_loss: 1.9165 - val_acc: 0.5015
# Epoch 61/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.4238 - acc: 0.5954 - val_loss: 2.0373 - val_acc: 0.4765
# Epoch 62/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.4162 - acc: 0.5991 - val_loss: 1.9241 - val_acc: 0.5078
# Epoch 63/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.4122 - acc: 0.5970 - val_loss: 1.9259 - val_acc: 0.4998
# Epoch 64/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.3988 - acc: 0.6001 - val_loss: 2.0118 - val_acc: 0.4854
# Epoch 65/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.3968 - acc: 0.6021 - val_loss: 1.9068 - val_acc: 0.5059
# Epoch 66/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.4025 - acc: 0.6026 - val_loss: 1.9488 - val_acc: 0.5029
# Epoch 67/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.3756 - acc: 0.6063 - val_loss: 1.8381 - val_acc: 0.5168
# Epoch 68/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.3731 - acc: 0.6055 - val_loss: 1.8482 - val_acc: 0.5175
# Epoch 69/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.3641 - acc: 0.6081 - val_loss: 2.0046 - val_acc: 0.5016
# Epoch 70/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.3633 - acc: 0.6096 - val_loss: 1.8828 - val_acc: 0.5149
# Epoch 71/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.3681 - acc: 0.6106 - val_loss: 2.0010 - val_acc: 0.4953
# Epoch 72/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.3463 - acc: 0.6128 - val_loss: 1.9170 - val_acc: 0.5157
# Epoch 73/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.3400 - acc: 0.6168 - val_loss: 1.8906 - val_acc: 0.5171
# Epoch 74/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.3321 - acc: 0.6152 - val_loss: 1.8996 - val_acc: 0.5093
# Epoch 75/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.3227 - acc: 0.6183 - val_loss: 1.9010 - val_acc: 0.5190
# Epoch 76/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.3056 - acc: 0.6223 - val_loss: 1.9021 - val_acc: 0.5147
# Epoch 77/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.3101 - acc: 0.6232 - val_loss: 1.9074 - val_acc: 0.5092
# Epoch 78/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.2991 - acc: 0.6250 - val_loss: 1.8674 - val_acc: 0.5277
# Epoch 79/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.2981 - acc: 0.6266 - val_loss: 2.0170 - val_acc: 0.4960
# Epoch 80/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.2956 - acc: 0.6248 - val_loss: 2.0049 - val_acc: 0.5071
# Epoch 81/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.2852 - acc: 0.6298 - val_loss: 2.1237 - val_acc: 0.4776
# Epoch 82/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.2760 - acc: 0.6309 - val_loss: 2.0141 - val_acc: 0.4917
# Epoch 83/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.2644 - acc: 0.6296 - val_loss: 1.9375 - val_acc: 0.5079
# Epoch 84/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.2689 - acc: 0.6321 - val_loss: 1.9081 - val_acc: 0.5167
# Epoch 85/100
# 250/250 [==============================] - 37s 147ms/step - loss: 1.2546 - acc: 0.6358 - val_loss: 2.0940 - val_acc: 0.4931
# Epoch 86/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.2565 - acc: 0.6371 - val_loss: 1.9764 - val_acc: 0.4990
# Epoch 87/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.2527 - acc: 0.6338 - val_loss: 1.9193 - val_acc: 0.5195
# Epoch 88/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.2497 - acc: 0.6381 - val_loss: 1.8592 - val_acc: 0.5230

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
y_pred=inception_net_model.predict(x_test)
# tf.one_hot(y_pred)
# y_pred=np.where(y_pred[0]=max(y_pred[0],1,0))
y_pred_proc=np.zeros((10000,100))
for i in range(0,10000):
    y_pred_proc[i][np.argmax(y_pred[i])]=1
print("Precision: "+ str(precision_score(y_test_proc, y_pred_proc, average='weighted')))
print("Recall: "+ str(recall_score(y_test_proc, y_pred_proc, average='weighted')))
print("Accuracy: "+ str(accuracy_score(y_test_proc, y_pred_proc)))
# Out:
# Precision: 0.5449313416494997
# Recall: 0.523
# Accuracy: 0.523

# %%
plt.plot(output.history['acc'])
plt.plot(output.history['val_acc'])
plt.legend(['Training Accuracy','Testing Accuracy'])

# %%
plt.plot(output.history['loss'])
plt.plot(output.history['val_loss'])
plt.legend(['Training loss','Testing loss'])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import datetime as dt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data()

y_proc=np.zeros((50000,100))
for i in range(0,50000):
    y_proc[i][y_train[i][0]]=1
y_test_proc=np.zeros((10000,100))
for i in range(0,10000):
    y_test_proc[i][y_test[i][0]]=1
y_proc.shape
input_shape=(32,32,3)
y_test_proc[0]
x_train=x_train.astype('float')/255
x_test=x_test.astype('float')/255

inputs = keras.Input(shape=input_shape)
x = layers.Conv2D(32, 3, activation='elu')(inputs)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)
x = layers.Conv2D(32, 3, activation='elu')(x)


#Inception1


conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)

conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_2 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_2)

conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2

conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_1)
# conv_1 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_2 = layers.Conv2D(32, (1,7), padding='same', activation='elu')(conv_2)
# conv_2 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)


# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception3
conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
conv_11 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_1)

conv_12 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
conv_21 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_2)

conv_22 = layers.Conv2D(32, (3,1), padding='same', activation='elu')(conv_2)

conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

x = layers.concatenate([conv_11,conv_12,conv_3,conv_4,conv_21,conv_22], axis=3)

# conv_1 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_1 = layers.Conv2D(32, (3,3), padding='same', activation='elu')(conv_1)
# conv_11 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_1)

# conv_12 = layers.Conv2D(32, (7,1), padding='same', activation='elu')(conv_1)

# conv_2 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)
# conv_21 = layers.Conv2D(32, (1,3), padding='same', activation='elu')(conv_2)

# conv_22 = layers.Conv2D(32, (3,1), padding='same', activation='elu')(conv_2)

# conv_3 = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)
# conv_3 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(conv_3)

# conv_4 = layers.Conv2D(32, (1,1), padding='same', activation='elu')(x)

# x = layers.concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#end

# x = layers.MaxPool2D((3,3), strides=(1,1), padding='same')(x)



# x = layers.MaxPooling2D(2)(x)
x = layers.Conv2D(32, 3, activation='relu')(x)
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.AveragePooling2D(4)(x)
x=layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
outputs = layers.Dense(100, activation='softmax')(x)

inception_net_model = keras.Model(inputs, outputs)

inception_net_model.load_weights('../weights/inception_sgd_noreg.hdf5')

from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
y_pred=inception_net_model.predict(x_test)
# tf.one_hot(y_pred)
# y_pred=np.where(y_pred[0]=max(y_pred[0],1,0))
y_pred_proc=np.zeros((10000,100))
for i in range(0,10000):
    y_pred_proc[i][np.argmax(y_pred[i])]=1
print("Precision: "+ str(precision_score(y_test_proc, y_pred_proc, average='weighted')))
print("Recall: "+ str(recall_score(y_test_proc, y_pred_proc, average='weighted')))
print("Accuracy: "+ str(accuracy_score(y_test_proc, y_pred_proc)))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step
# Precision: 0.5472957734979342
# Recall: 0.5277
# Accuracy: 0.5277
